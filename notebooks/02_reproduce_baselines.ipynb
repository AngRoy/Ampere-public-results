# %% [markdown]
# # 02 Reproduce Classical And Tree Baselines
#
# Regenerates corrected canonical data, classical baselines, and tree baselines from raw CSVs, then checks the corrected headline values.

# %%
from pathlib import Path
import os
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "src").is_dir():
    ROOT = ROOT.parent
if str(ROOT / "src") not in sys.path:
    sys.path.insert(0, str(ROOT / "src"))

DATA_DIR = Path(os.environ.get("AMPERE_DATA_DIR", "data/raw"))
RUN_MODE = os.environ.get("AMPERE_RUN_MODE", "smoke")
SEEDS = [42, 123, 2026]
OUTPUT_DIR = Path(os.environ.get("AMPERE_OUTPUT_DIR", "runs"))

try:
    display
except NameError:
    display = print

print("ROOT= <repo root>")
print("DATA_DIR=", DATA_DIR)
print("RUN_MODE=", RUN_MODE)
print("OUTPUT_DIR=", OUTPUT_DIR)
# Out:
# ROOT= <repo root>
# DATA_DIR= data\raw
# RUN_MODE= smoke
# OUTPUT_DIR= runs

# %%
from ampere_public.publication import run_corrected_baseline_pipeline, verify_baseline_outputs

paths = run_corrected_baseline_pipeline(DATA_DIR, OUTPUT_DIR)
print(paths)
comparison = verify_baseline_outputs(paths["tree"])
display(comparison)
print("Corrected baseline reproduction passed.")
# Out:
# $ python scripts/run_classical_baselines.py --datasets appliance_8ch --processed-dir runs/processed --output-dir runs/reconstruction/classical --figures-dir runs/figures/classical --report-path runs/reports/classical_baseline_report.md
# {
#   "status": "ok",
#   "datasets": [
#     {
#       "dataset_id": "appliance_8ch",
#       "input_path": "runs/processed/appliance_8ch_long.parquet",
#       "input_rows": 360000,
#       "input_columns": 30,
#       "prediction_output": {
#         "path": "runs/reconstruction/classical/appliance_8ch_classical_predictions.parquet",
#         "format": "parquet",
#         "rows": 1800000,
#         "columns": 26
#       },
#       "method_metadata": {
#         "requested_methods": [
#           "mean_per_branch",
#           "zoh",
#           "linear",
#           "pchip",
#           "slope_aware_an"
#         ],
#         "executed_methods": [
#           "mean_per_branch",
#           "zoh",
#           "linear",
#           "pchip",
# ...
