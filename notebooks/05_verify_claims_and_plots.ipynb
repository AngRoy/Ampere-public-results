# %% [markdown]
# # 05 Verify Claims And Rebuild Plots
#
# Checks the expected corrected result tables and regenerates lightweight summary plots from the published expected CSVs.

# %%
from pathlib import Path
import os
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "src").is_dir():
    ROOT = ROOT.parent
if str(ROOT / "src") not in sys.path:
    sys.path.insert(0, str(ROOT / "src"))

DATA_DIR = Path(os.environ.get("AMPERE_DATA_DIR", "data/raw"))
RUN_MODE = os.environ.get("AMPERE_RUN_MODE", "smoke")
SEEDS = [42, 123, 2026]
OUTPUT_DIR = Path(os.environ.get("AMPERE_OUTPUT_DIR", "runs"))

try:
    display
except NameError:
    display = print

print("ROOT= <repo root>")
print("DATA_DIR=", DATA_DIR)
print("RUN_MODE=", RUN_MODE)
print("OUTPUT_DIR=", OUTPUT_DIR)
# Out:
# ROOT= <repo root>
# DATA_DIR= data\raw
# RUN_MODE= smoke
# OUTPUT_DIR= runs

# %%
from ampere_public.publication import verify_expected_claims, rebuild_summary_plots, EXPECTED_RESULTS

headline = verify_expected_claims()
display(headline)
print("Expected corrected claims:")
for key, value in EXPECTED_RESULTS.items():
    print(f"  {key}: {value}")

paths = rebuild_summary_plots(output_dir=OUTPUT_DIR / "verified_figures")
for path in paths:
    print("wrote", path)
print("Claim verification and plot rebuild passed.")
# Out:
#              family      seed  ... transition_mae  stable_mae
# 0  Corrected linear         -  ...            NaN         NaN
# 1  Best online tree         -  ...            NaN         NaN
# 2          DwellMLP  mean+std  ...      73.454975   21.273500
# 3   DwellObserver-T  mean+std  ...      74.129155   18.157229
#
# [4 rows x 8 columns]
# Expected corrected claims:
#   linear_dwell_mae: 75.39441704611784
#   best_online_tree_dwell_mae: 78.19738926083397
#   dwellmlp_mean: 43.83111707887881
#   dwellmlp_std: 2.8978905133964625
#   dwellobserver_t_mean: 40.64386529001349
#   dwellobserver_t_std: 1.2933353270642651
# wrote runs\verified_figures\headline_dwell_mae.png
# wrote runs\verified_figures\per_branch_neural_mae.png
# Claim verification and plot rebuild passed.
